# %%
ColabNotebook = 'google.colab' in str(get_ipython())

if ColabNotebook:
    # monta G-drive en entorno COLAB
    from google.colab import drive
    drive.mount('/content/drive/')

    # carpeta donde se encuentran archivos .py auxiliares
    FUENTES_DIR = '/content/drive/MyDrive/Colab Notebooks/FUENTES/'
    DATOS_DIR = '/content/drive/MyDrive/Colab Notebooks/DATOS/'      # carpeta donde se encuentran los datasets
else:
    # configuración para notebook con instalación LOCAL
    FUENTES_DIR = '../Fuentes'         # carpeta donde se encuentran archivos .py auxiliares
    DATOS_DIR   = '../Datos/' # carpeta donde se encuentran los datasets

# agrega ruta de busqueda donde tenemos archivos .py
import sys
sys.path.append(FUENTES_DIR)

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.utils import to_categorical

import matplotlib.pyplot as plt
import numpy as np
from sklearn import preprocessing, metrics, model_selection 
import pandas as pd

# %%
df = pd.read_csv(DATOS_DIR + 'Iris.csv')

# Tomamos todas las columnas menos la última
X = np.array(df.iloc[:, 0:-1])
Y = np.array(df.iloc[:,-1])
encoder = preprocessing.LabelEncoder()
Y = encoder.fit_transform(Y)
Y_bin= to_categorical(Y)

# %%
#--- CONJUNTOS DE ENTRENAMIENTO Y TESTEO ---
X_train, X_test, Y_train, Y_test = model_selection.train_test_split( \
        X, Y_bin, test_size=0.20) #, random_state=42)

# %%
normalizarEntrada = 1  # 1 si normaliza; 0 si no

if normalizarEntrada:
    # Escala los valores entre 0 y 1
    min_max_scaler = preprocessing.StandardScaler()
    X_train = min_max_scaler.fit_transform(X_train)
    X_test = min_max_scaler.transform(X_test)

# %% [markdown]
# ### Definición del modelo

# %%
# Crear un modelo de capas secuenciales
model=Sequential()

# Agregar las capas al modelo
model.add(Input(shape=[4]))
model.add(Dense(2, activation='tanh'))
model.add(Dense(3, activation='softmax'))

# Imprimir un resumen del modelo
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2)                 10
#
#  dense_1 (Dense)             (None, 3)                 9
#
# =================================================================
# Total params: 19
# Trainable params: 19
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Configuración para entrenamiento
model.compile(optimizer=SGD(learning_rate=0.05), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
es = EarlyStopping(monitor='val_accuracy', patience=30, min_delta=1e-06, restore_best_weights=True, baseline=0.5)

H = model.fit(x = X_train, y = Y_train, epochs=4000, batch_size = 20, 
              validation_data = (X_test, Y_test),  callbacks=[es])
# Out:
# Epoch 1/4000
# 6/6 [==============================] - 1s 70ms/step - loss: 1.1159 - accuracy: 0.3750 - val_loss: 0.9792 - val_accuracy: 0.6333
# Epoch 2/4000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9802 - accuracy: 0.5500 - val_loss: 0.8715 - val_accuracy: 0.7000
# Epoch 3/4000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.8826 - accuracy: 0.6167 - val_loss: 0.7957 - val_accuracy: 0.7000
# Epoch 4/4000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.8086 - accuracy: 0.6583 - val_loss: 0.7397 - val_accuracy: 0.7000
# Epoch 5/4000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.7542 - accuracy: 0.6833 - val_loss: 0.6973 - val_accuracy: 0.7333
# Epoch 6/4000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.7111 - accuracy: 0.6917 - val_loss: 0.6634 - val_accuracy: 0.7333
# Epoch 7/4000
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6762 - accuracy: 0.7167 - val_loss: 0.6360 - val_accuracy: 0.7333
# Epoch 8/4000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6487 - accuracy: 0.7250 - val_loss: 0.6131 - val_accuracy: 0.7333
# Epoch 9/4000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6243 - accuracy: 0.7417 - val_loss: 0.5937 - val_accuracy: 0.7000
# Epoch 10/4000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6051 - accuracy: 0.7500 - val_loss: 0.5771 - val_accuracy: 0.7333
# Epoch 11/4000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5879 - accuracy: 0.7500 - val_loss: 0.5627 - val_accuracy: 0.7667
# Epoch 12/4000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5741 - accuracy: 0.7667 - val_loss: 0.5501 - val_accuracy: 0.8000
# Epoch 13/4000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5614 - accuracy: 0.8000 - val_loss: 0.5389 - val_accuracy: 0.8000
# Epoch 14/4000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5488 - accuracy: 0.8083 - val_loss: 0.5290 - val_accuracy: 0.8000
# Epoch 15/4000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5386 - accuracy: 0.8167 - val_loss: 0.5201 - val_accuracy: 0.8000
# Epoch 16/4000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5291 - accuracy: 0.8333 - val_loss: 0.5120 - val_accuracy: 0.8000
# Epoch 17/4000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5210 - accuracy: 0.8333 - val_loss: 0.5046 - val_accuracy: 0.8000
# Epoch 18/4000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5128 - accuracy: 0.8333 - val_loss: 0.4979 - val_accuracy: 0.8000
# Epoch 19/4000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5057 - accuracy: 0.8417 - val_loss: 0.4917 - val_accuracy: 0.8333
# Epoch 20/4000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4987 - accuracy: 0.8417 - val_loss: 0.4859 - val_accuracy: 0.8333
# Epoch 21/4000
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4927 - accuracy: 0.8417 - val_loss: 0.4806 - val_accuracy: 0.8333
# Epoch 22/4000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4866 - accuracy: 0.8417 - val_loss: 0.4756 - val_accuracy: 0.8333
# Epoch 23/4000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4811 - accuracy: 0.8417 - val_loss: 0.4710 - val_accuracy: 0.8333
# Epoch 24/4000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4757 - accuracy: 0.8417 - val_loss: 0.4666 - val_accuracy: 0.8333
# Epoch 25/4000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4707 - accuracy: 0.8417 - val_loss: 0.4624 - val_accuracy: 0.8333
# Epoch 26/4000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4657 - accuracy: 0.8417 - val_loss: 0.4585 - val_accuracy: 0.8333
# Epoch 27/4000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4608 - accuracy: 0.8417 - val_loss: 0.4547 - val_accuracy: 0.8333
# Epoch 28/4000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4562 - accuracy: 0.8417 - val_loss: 0.4511 - val_accuracy: 0.8333
# Epoch 29/4000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4518 - accuracy: 0.8417 - val_loss: 0.4477 - val_accuracy: 0.8333
# Epoch 30/4000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4473 - accuracy: 0.8583 - val_loss: 0.4444 - val_accuracy: 0.8333
# Epoch 31/4000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4430 - accuracy: 0.8583 - val_loss: 0.4412 - val_accuracy: 0.8333
# Epoch 32/4000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4385 - accuracy: 0.8583 - val_loss: 0.4381 - val_accuracy: 0.8333
# Epoch 33/4000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4345 - accuracy: 0.8583 - val_loss: 0.4352 - val_accuracy: 0.8333
# Epoch 34/4000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4307 - accuracy: 0.8583 - val_loss: 0.4322 - val_accuracy: 0.8333
# Epoch 35/4000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4267 - accuracy: 0.8583 - val_loss: 0.4294 - val_accuracy: 0.8333
# Epoch 36/4000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4225 - accuracy: 0.8583 - val_loss: 0.4266 - val_accuracy: 0.8333
# Epoch 37/4000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4187 - accuracy: 0.8667 - val_loss: 0.4238 - val_accuracy: 0.8333
# Epoch 38/4000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4146 - accuracy: 0.8667 - val_loss: 0.4212 - val_accuracy: 0.8333
# Epoch 39/4000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4107 - accuracy: 0.8750 - val_loss: 0.4185 - val_accuracy: 0.8333
# Epoch 40/4000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4075 - accuracy: 0.8833 - val_loss: 0.4159 - val_accuracy: 0.8333
# Epoch 41/4000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4035 - accuracy: 0.8750 - val_loss: 0.4132 - val_accuracy: 0.8667
# Epoch 42/4000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3997 - accuracy: 0.8750 - val_loss: 0.4106 - val_accuracy: 0.8667
# Epoch 43/4000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3958 - accuracy: 0.8750 - val_loss: 0.4080 - val_accuracy: 0.8667
# Epoch 44/4000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3918 - accuracy: 0.8833 - val_loss: 0.4054 - val_accuracy: 0.8667
# Epoch 45/4000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3880 - accuracy: 0.8833 - val_loss: 0.4028 - val_accuracy: 0.8667
# Epoch 46/4000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3841 - accuracy: 0.8833 - val_loss: 0.4002 - val_accuracy: 0.8667
# Epoch 47/4000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3808 - accuracy: 0.8833 - val_loss: 0.3976 - val_accuracy: 0.8667
# Epoch 48/4000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3767 - accuracy: 0.8833 - val_loss: 0.3950 - val_accuracy: 0.8667
# Epoch 49/4000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3735 - accuracy: 0.8833 - val_loss: 0.3924 - val_accuracy: 0.8667
# Epoch 50/4000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3695 - accuracy: 0.8917 - val_loss: 0.3897 - val_accuracy: 0.8667
# Epoch 51/4000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3654 - accuracy: 0.8917 - val_loss: 0.3871 - val_accuracy: 0.8667
# Epoch 52/4000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3615 - accuracy: 0.8917 - val_loss: 0.3844 - val_accuracy: 0.8667
# Epoch 53/4000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3579 - accuracy: 0.9000 - val_loss: 0.3816 - val_accuracy: 0.8667
# Epoch 54/4000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3545 - accuracy: 0.9000 - val_loss: 0.3788 - val_accuracy: 0.8667
# Epoch 55/4000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3501 - accuracy: 0.9000 - val_loss: 0.3760 - val_accuracy: 0.8667
# Epoch 56/4000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3468 - accuracy: 0.9083 - val_loss: 0.3732 - val_accuracy: 0.8667
# Epoch 57/4000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3434 - accuracy: 0.9083 - val_loss: 0.3703 - val_accuracy: 0.8667
# Epoch 58/4000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3390 - accuracy: 0.9083 - val_loss: 0.3674 - val_accuracy: 0.8667
# Epoch 59/4000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3359 - accuracy: 0.9083 - val_loss: 0.3644 - val_accuracy: 0.8667
# Epoch 60/4000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3313 - accuracy: 0.9167 - val_loss: 0.3614 - val_accuracy: 0.8667
# Epoch 61/4000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3279 - accuracy: 0.9167 - val_loss: 0.3583 - val_accuracy: 0.8667
# Epoch 62/4000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3239 - accuracy: 0.9333 - val_loss: 0.3553 - val_accuracy: 0.8667
# Epoch 63/4000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3203 - accuracy: 0.9333 - val_loss: 0.3521 - val_accuracy: 0.8667
# Epoch 64/4000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3166 - accuracy: 0.9333 - val_loss: 0.3489 - val_accuracy: 0.8667
# Epoch 65/4000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3129 - accuracy: 0.9333 - val_loss: 0.3456 - val_accuracy: 0.8667
# Epoch 66/4000
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3094 - accuracy: 0.9333 - val_loss: 0.3423 - val_accuracy: 0.8667
# Epoch 67/4000
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3050 - accuracy: 0.9417 - val_loss: 0.3390 - val_accuracy: 0.8667
# Epoch 68/4000
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3021 - accuracy: 0.9417 - val_loss: 0.3355 - val_accuracy: 0.8667
# Epoch 69/4000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2982 - accuracy: 0.9417 - val_loss: 0.3321 - val_accuracy: 0.8667
# Epoch 70/4000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2949 - accuracy: 0.9500 - val_loss: 0.3286 - val_accuracy: 0.8667
# Epoch 71/4000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2904 - accuracy: 0.9500 - val_loss: 0.3251 - val_accuracy: 0.8667

# %%
print("épocas = %d" % len(H.history["val_accuracy"]))   
print("Epocas = %d" % es.stopped_epoch)
# Out:
# épocas = 71
# Epocas = 70

# %%
# predecir la salida del modelo
Y_pred = model.predict(X_train)
Y_pred2 = np.argmax(Y_pred,axis=1)

Y_true =  np.argmax(Y_train,axis=1)

print("%% aciertos X_train : %.3f" % metrics.accuracy_score(Y_true, Y_pred2))

Y_test_pred = model.predict(X_test)
Y_test_pred2 = np.argmax(Y_test_pred,axis=1)

Y_test_true =  np.argmax(Y_test,axis=1)

print("%% aciertos X_test : %.3f" % metrics.accuracy_score(Y_test_true, Y_test_pred2))
# Out:
# 4/4 [==============================] - 0s 3ms/step
# % aciertos X_train : 0.875
# 1/1 [==============================] - 0s 25ms/step
# % aciertos X_test : 0.867

# %%
report = metrics.classification_report(Y_true, Y_pred2)
print("Confusion matrix Training:\n%s" % report) 

MM = metrics.confusion_matrix(Y_true, Y_pred2)
print("Confusion matrix:\n%s" % MM)
# Out:
# Confusion matrix Training:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        39
#            1       1.00      0.63      0.78        41
#            2       0.73      1.00      0.84        40
#
#     accuracy                           0.88       120
#    macro avg       0.91      0.88      0.87       120
# weighted avg       0.91      0.88      0.87       120
#
# Confusion matrix:
# [[39  0  0]
#  [ 0 26 15]
#  [ 0  0 40]]

# %%
# dibuja accuracy del progreso del entrenamiento
accuracy = np.array(H.history["accuracy"])
val_accuracy = np.array(H.history["val_accuracy"])

N = np.arange(0, len(accuracy))
plt.figure()
#plt.plot(N, H.history["loss"], label="train_loss")
#plt.plot(N, H.history["val_loss"], label="val_loss")
plt.plot(N, 100*accuracy, label="train_acc")
plt.plot(N, 100*val_accuracy, label="val_acc")
plt.title("Efectividad de Entrenamiento")
plt.xlabel("Época #")
plt.ylabel("Efectividad")
plt.legend(loc="lower right")

# %%
# dibuja accuracy del progreso del entrenamiento
accuracy = np.array(H.history["loss"])
val_accuracy = np.array(H.history["val_loss"])

N = np.arange(0, len(accuracy))
plt.figure()
#plt.plot(N, H.history["loss"], label="train_loss")
#plt.plot(N, H.history["val_loss"], label="val_loss")
plt.plot(N, 100*accuracy, label="train_loss")
plt.plot(N, 100*val_accuracy, label="val_loss")
plt.title("Error")
plt.xlabel("Época #")
plt.ylabel("loss")
plt.legend(loc="lower left")
